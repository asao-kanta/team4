# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('meta_df.csv')

# %%
data.head()
# Out:
#    img_id  img_width  img_height            img_file  cat_id  \
# 0       0       1537        2049  batch_1/000006.jpg       6
# 1       1       1537        2049  batch_1/000008.jpg      18
# 2       1       1537        2049  batch_1/000008.jpg      14
# 3       2       1537        2049  batch_1/000010.jpg       5
# 4       2       1537        2049  batch_1/000010.jpg       7
#
#                cat_name supercategory  ann_id      x      y   width  height  \
# 0          Glass bottle        Bottle       1  517.0  127.0   447.0  1322.0
# 1           Meal carton        Carton       2    1.0  457.0  1429.0  1519.0
# 2          Other carton        Carton       3  531.0  292.0  1006.0   672.0
# 3  Clear plastic bottle        Bottle       4  632.0  987.0   500.0   374.0
# 4    Plastic bottle cap    Bottle cap       5  632.0  989.0    44.0    51.0
#
#         area
# 0   403954.0
# 1  1071259.5
# 2    99583.5
# 3    73832.5
# 4      915.0

# %%
pickup_data = data.drop_duplicates(keep=False,subset='img_id')
pickup_data
# Out:
#       img_id  img_width  img_height            img_file  cat_id  \
# 0          0       1537        2049  batch_1/000006.jpg       6
# 9          4       1537        2049  batch_1/000026.jpg      12
# 16         6       1537        2049  batch_1/000055.jpg      11
# 19         8       1537        2049  batch_1/000005.jpg       5
# 45        14       1537        2049  batch_1/000056.jpg       4
# ...      ...        ...         ...                 ...     ...
# 4711    1482       1824        4000  batch_9/000082.jpg      39
# 4712    1483       1824        4000  batch_9/000083.jpg      12
# 4758    1491       4000        1824  batch_9/000091.jpg       5
# 4759    1492       1824        4000  batch_9/000092.jpg       5
# 4775    1496       1824        4000  batch_9/000096.jpg      55
#
#                    cat_name          supercategory  ann_id       x       y  \
# 0              Glass bottle                 Bottle       1   517.0   127.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.xticks(rotation=30)
g = sns.countplot(x='supercategory',data=pickup_data)
#g.set_xticklabels(rotation = 30)

# %%
use_pickup_data = pickup_data.query("supercategory==['Bottle','Can','Cup','Carton','Plastic bag & wrapper','Bottle cap','Other plastic']")
use_pickup_data
# Out:
#       img_id  img_width  img_height            img_file  cat_id  \
# 0          0       1537        2049  batch_1/000006.jpg       6
# 9          4       1537        2049  batch_1/000026.jpg      12
# 16         6       1537        2049  batch_1/000055.jpg      11
# 19         8       1537        2049  batch_1/000005.jpg       5
# 45        14       1537        2049  batch_1/000056.jpg       4
# ...      ...        ...         ...                 ...     ...
# 4688    1477       4000        1824  batch_9/000077.jpg       7
# 4711    1482       1824        4000  batch_9/000082.jpg      39
# 4712    1483       1824        4000  batch_9/000083.jpg      12
# 4758    1491       4000        1824  batch_9/000091.jpg       5
# 4759    1492       1824        4000  batch_9/000092.jpg       5
#
#                    cat_name          supercategory  ann_id          x  \
# 0              Glass bottle                 Bottle       1   517.0000
# ...

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=30)
g = sns.countplot(x='supercategory',data=use_pickup_data)

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=30)
g = sns.countplot(x='cat_name',data=pickup_data)

# %%
pickup_data['cat_name'].unique()
# Out:
# array(['Glass bottle', 'Drink can', 'Aerosol', 'Clear plastic bottle',
#        'Other plastic bottle', 'Paper cup', 'Egg carton', 'Other carton',
#        'Paper bag', 'Crisp packet', 'Spread tub', 'Garbage bag',
#        'Foam cup', 'Plastic film', 'Food waste', 'Metal bottle cap',
#        'Unlabeled litter', 'Aluminium foil', 'Normal paper', 'Shoe',
#        'Other plastic', 'Corrugated carton', 'Other plastic wrapper',
#        'Plastic bottle cap', 'Plastic straw', 'Styrofoam piece',
#        'Cigarette', 'Rope & strings', 'Plastic glooves', 'Tissues',
#        'Magazine paper', 'Single-use carrier bag', 'Wrapping paper',
#        'Disposable food container', 'Disposable plastic cup',
#        'Aluminium blister pack', 'Plastic utensils', 'Plastic lid',
#        'Drink carton', 'Battery', 'Scrap metal', 'Tupperware', 'Pop tab',
#        'Broken glass', 'Meal carton', 'Foam food container',
#        'Other plastic cup', 'Food Can', 'Squeezable tube',
# ...

# %%
df = pickup_data.query("cat_name==['Glass bottle', 'Drink can', 'Clear plastic bottle','Paper cup', 'Other carton','Crisp packet', 'Plastic film','Metal bottle cap','Unlabeled litter', 'Aluminium foil', 'Normal paper','Other plastic','Other plastic wrapper','Plastic bottle cap', 'Plastic straw','Styrofoam piece','Rope & strings','Single-use carrier bag','Disposable plastic cup',]")
plt.figure(figsize=(30,10))
plt.xticks(rotation=30)
g = sns.countplot(x='cat_name',data=df)

# %%
df['img_id']=np.arange(len(df))
df_1 = df.drop(['cat_id','ann_id'],axis=1)
df_1
#'x','y','width','height','area'は考え中
# Out:
# C:\Users\kd207\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       img_id  img_width  img_height            img_file  \
# 0          0       1537        2049  batch_1/000006.jpg
# 9          1       1537        2049  batch_1/000026.jpg
# 19         2       1537        2049  batch_1/000005.jpg
# 51         3       1537        2049  batch_1/000003.jpg
# 52         4       1537        2049  batch_1/000011.jpg
# ...      ...        ...         ...                 ...
# 4711     509       1824        4000  batch_9/000082.jpg
# 4712     510       1824        4000  batch_9/000083.jpg
# 4758     511       4000        1824  batch_9/000091.jpg
# ...

# %%
#labelの作成
#'Glass bottle', 'Drink can', 'Clear plastic bottle','Paper cup', 'Other carton','Crisp packet', 'Plastic film','Metal bottle cap','Unlabeled litter', 'Aluminium foil', 'Normal paper','Other plastic','Other plastic wrapper','Plastic bottle cap', 'Plastic straw','Styrofoam piece','Rope & strings','Single-use carrier bag','Disposable plastic cup'
nonflammable,flammable,bottle or petbottle

# %%
data_1 = pickup_data.query("supercategory==['Bottle']")
#,'Can','Cup','Carton','Plastic bag & wrapper','Bottle cap','Other plastic'
sns.countplot(x='cat_name',data=data_1)

# %%
#csvfileへの書き込み
df_1.to_csv('df_1.csv')
